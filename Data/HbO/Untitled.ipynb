# %%
from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from pyts.datasets import load_gunpoint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
subj = 13
stim = 3


data = pd.read_csv('Sub'+str(subj)+'_Visual_'+str(stim)+'_HbO.csv',header= None)
#data = pd.read_csv('Sub'+str(subj)+'_Motor_'+str(stim)+'_HbO.csv',header= None)

# %%
data
# Out:
#            0          1          2          3          4          5   \
# 0   28.063051  21.795559  63.804522   5.669910  19.813662   3.821186
# 1   25.518364  25.057113  63.931380   5.371284  25.335448   4.526205
# 2   26.495472  22.540007  60.647327   8.340582  15.868391  10.710194
# 3   23.461077  24.003043  66.855785   7.127459  25.042757   5.086522
# 4   26.124976  27.768794  69.811582   6.672242  25.421695   6.182602
# ..        ...        ...        ...        ...        ...        ...
# 93  26.209427  28.853504  59.339113   5.817684  18.123064  11.112509
# 94  29.713316  26.044154  49.315259  16.757836  16.002511   9.967691
# 95  25.818190  22.202285  59.236035   5.722296  19.819514   2.807879
# 96  25.462085  29.390061  71.159555   6.353478  17.966595  10.010476
# 97  28.548281  23.599110  60.976754   6.653368  25.165598   5.723392
#
#             6          7           8          9   ...          20         21  \
# ...

# %%
plt(data['0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7fd0bb0359ef> in <module>
# ----> 1 plt(data['0'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %%
gafs = GramianAngularField(method= 'summation')

# %%
im = gafs.fit_transform(data)
new_image = plt.imshow(im[1])
fig3 = plt.gcf()
# show the plot
#plt.show()
#Save figure 
fig3.savefig('/Users/talukdarraianferdous/Documents/fNIRS Data/CPGM/GAF_FIT/Images/HbO/Sub'+str(subj)+'/Visual/Sub'+str(subj)+'_Visual'+str(stim)+'_HbO', dpi=500)
#fig3.savefig('/Users/talukdarraianferdous/Documents/fNIRS Data/CPGM/GAF_FIT/Images/HbO/Sub'+str(subj)+'/Motor/Sub'+str(subj)+'_Motor'+str(stim)+'_HbO', dpi=500)
    
plt.show()
